# %% [markdown]
# # (PSL) Coding Assignment 2

# %% [markdown]
# ## Part I: Implement Lasso

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load Data

# %%
myData = pd.read_csv("data/Coding2_Data.csv")
var_names = myData.columns
y = myData[['Y']].to_numpy()
X = myData.drop(['Y'], axis = 1).to_numpy()

# %%
X.shape, len(y)
# Out:
# ((506, 13), 506)

# %% [markdown]
# ### CD for Lasso

# %%
# b[j] = one_var_lasso(r, X_j, lam_seq[m])

def one_var_lasso(r, z, lam):
    
    #################
    # Your CODE
    #################
    
    a = (np.transpose(r) @ z)/(np.sum(np.square(z)))
    
    lam_new = (2*r.shape[0]*lam)/(np.sum(np.square(z)))
    
    if (a > lam_new/2):
        return a - lam_new/2
    elif (np.abs(a) <= lam_new/2):
        return 0
    elif(a < -lam_new/2):
        return a + lam_new/2
    else:
        return None

# %%
q = np.array([[1, 2], [3, 4]])
print(q)
# Out:
# [[1 2]
#  [3 4]]

# %%
def standardize(X):
    return (X - np.mean(X))/np.std(X) #, center

# %%
def MyLasso(X, y, lam_seq, maxit = 100):
    
    # Input
    # X: n-by-p design matrix without the intercept 
    # y: n-by-1 response vector 
    # lam.seq: sequence of lambda values (arranged from large to small)
    # maxit: number of updates for each lambda 
    
    # Output
    # B: a (p+1)-by-len(lam.seq) coefficient matrix 
    #    with the first row being the intercept sequence 

  
    n, p = X.shape
    nlam = len(lam_seq)
    B = np.zeros((p+1, nlam))
    
    ##############################
    # YOUR CODE: 
    # (1) newX = Standardized X; 
    # (2) Record the centers and scales used in (1) 
    ##############################
    
#     newX = np.apply_along_axis(standardize, 0, X)
#     centers = np.mean(X,axis=0)
#     std_devs = np.std(X,axis=0)

#     col = 0
    
#     print(X[col,:])
#     print("+++++++++")
#     print(np.mean(X[col,:]))
#     print(np.std(X[col,:]))
    
#     asdf = (X[:,col] - np.mean(X[:,col]))/np.std(X[:,col])
#     print(asdf)
#     print("===============")
#     print(newX[col,:])
    
######################################

    newX = np.zeros(X.shape)
    scales = np.zeros(1)
    means = []
    
    centers = np.mean(X,axis=0)
    std_devs = np.std(X,axis=0)
    
    print(X[:,0].shape)
    print(centers)
    
    for i in range(p):
        newX[:,i] =  (X[:,i] - centers[i])/std_devs[i]
        means.append(np.mean(X[:,i]))
#     print(means.shape)
    
  
    print(X.shape)
    print(B.shape)
    print(newX.shape)
    
    print("aaaaaaaaaaaaaaa")
    print(means[0])
    print(np.mean(X[:,0]))
    print(centers[0])
    
######################################


    # Initilize coef vector b and residual vector r
    b = np.zeros(p)
    r = y

    
    # Triple nested loop
    for m in range(nlam):
        for step in range(maxit):
            for j in range(p):
                X_j = newX[:, j].reshape(-1,1)
                r = r + X_j * b[j]
                b[j] = one_var_lasso(r, X_j, lam_seq[m])
                r = r - X_j * b[j]
        B[1:, m] = b 
    
    ##############################
    # YOUR CODE:
    # Scale back the coefficients;
    # Update the intercepts stored in B[, 1]
    ##############################

    
#     print(X.shape)
#     print(newX.shape)
    print(std_devs.shape)
#     print(centers.shape)

      
    for i in range(p):
        B[i+1,:] = (B[i+1,:] * std_devs[i]) 
    
    
    print("B")
#     print(B.shape)
#     print(B[:,1:].shape)
#     print(B[1:,:].shape)
    print(B[1:].shape)
    

  
    
    print(B.shape)
    B[0,:] = np.mean(y) - (centers @ B[1:,:])
#     print(B[0,:])
    print(B[:,0].shape)
#     print(B)
    
    return(B)

# %%
a = np.zeros(shape=(3, 2))
a[:,0] = 2
a
# Out:
# array([[2., 0.],
#        [2., 0.],
#        [2., 0.]])

# %%
log_lam_seq = np.linspace(-1, -8, num = 80)
lam_seq = np.exp(log_lam_seq)
myout = MyLasso(X, y, lam_seq, maxit = 100)
# Out:
# (506,)
# [-0.75981147  1.10528238  2.11692659  0.05037714 -0.61877895  1.78617584
#   4.96715614  1.14392498  1.83091395  5.83062688  2.11904235  3.49060149
#   3.34941278]
# (506, 13)
# (14, 80)
# (506, 13)
# aaaaaaaaaaaaaaa
# -0.7598114653471035
# -0.7598114653471035
# -0.7598114653471035
# (13,)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [717], in <cell line: 3>()
#       1 log_lam_seq = np.linspace(-1, -8, num = 80)
#       2 lam_seq = np.exp(log_lam_seq)
# ----> 3 myout = MyLasso(X, y, lam_seq, maxit = 100)
#
# Input In [715], in MyLasso(X, y, lam_seq, maxit)
#      95 #     print(centers.shape)
#      98     for i in range(p):
# ---> 99         B[i+1,:] = (B[i+1,:] * std_devs[i]) + centers
#     102     print("B")
#     103 #     print(B.shape)
#     104 #     print(B[:,1:].shape)
#     105 #     print(B[1:,:].shape)
#
# ValueError: operands could not be broadcast together with shapes (80,) (13,)

# %%
p, _ = myout.shape
plt.figure(figsize = (12,8))

for i in range(p-1):
    plt.plot(log_lam_seq, myout[i+1, :], label = var_names[i])

plt.xlabel('Log Lambda')
plt.ylabel('Coefficients')
plt.title('Lasso Paths - Numpy implementation')
plt.legend()
plt.axis('tight')
# Out:
# (-8.35, -0.6499999999999999, -0.3140575718302737, 0.6863457967681222)

# %% [markdown]
# ### Check the Accuracy

# %% [markdown]
# Compare the accuracy of your algorithm against the output from glmnet. The maximum difference between the two coefficient matrices should be less than 0.005.

# %%
lasso_coef = pd.read_csv("data/Coding2_lasso_coefs.csv").to_numpy()
lasso_coef.shape
# Out:
# (14, 80)

# %%
plt.figure(figsize = (12,8))

for i in range(p-1):
    plt.plot(log_lam_seq, lasso_coef[i+1, :], label = var_names[i])

plt.xlabel('Log Lambda')
plt.ylabel('Coefficients')
plt.title('Lasso Paths - Numpy implementation')
plt.legend()
plt.axis('tight')
# Out:
# (-8.35, -0.6499999999999999, -0.308843688719263, 0.49920481030861696)

# %%
abs(myout - lasso_coef).max()
# Out:
# 0.9087334371388742

# %%
print(lasso_coef[0])
# Out:
# [3.03451287 3.03526058 3.13419906 3.224748   3.30761882 3.38346258
#  3.45287514 3.51640183 3.57454176 3.62775169 3.67644966 3.72101827
#  3.76180767 3.79913832 3.83340673 3.87429587 3.91381812 3.90589479
#  3.89883334 3.89237139 3.88679083 3.84878634 3.80202818 3.75840301
#  3.71846457 3.68202949 3.65352038 3.62749709 3.60368223 3.58245745
#  3.5624735  3.54417257 3.52742326 3.54639886 3.59064823 3.62952976
#  3.66427418 3.69604635 3.72512493 3.75246817 3.77684495 3.79907346
#  3.8194157  3.81548045 3.8098448  3.82690168 3.85833056 3.88719763
#  3.91401864 3.93833216 3.96077467 3.98512467 4.00459848 4.01173776
#  4.02416922 4.03591855 4.04554626 4.05475778 4.06330791 4.07049326
#  4.07757029 4.08420651 4.0896737  4.09764765 4.10351642 4.10960399
#  4.114632   4.11960423 4.12436593 4.1281532  4.13187026 4.13547737
#  4.13956112 4.14176066 4.14415675 4.14658689 4.14896269 4.15089543
#  4.15272625 4.15448641]

# %%
print(myout[0])
# Out:
# [3.03451287 3.03451287 3.05935445 3.14159988 3.21687127 3.28576
#  3.34880728 3.40650845 3.45931683 3.50764729 3.55187956 3.59236114
#  3.62941007 3.66331742 3.66944421 3.6358967  3.60283364 3.57066425
#  3.54122267 3.51427761 3.48961736 3.46704819 3.44646552 3.43585091
#  3.42613637 3.41724558 3.40910868 3.40166176 3.3948463  3.38860876
#  3.3827869  3.37736597 3.3724047  3.36786412 3.36370857 3.35990539
#  3.3551762  3.34914318 3.34362174 3.34867418 3.36114571 3.37152656
#  3.38102716 3.37221647 3.35740294 3.34384553 3.33143773 3.32008205
#  3.30968928 3.30017777 3.29147279 3.28350596 3.27758251 3.27624491
#  3.27502073 3.27390036 3.27287499 3.27193657 3.27107772 3.26969636
#  3.26725033 3.26501171 3.26296291 3.26108785 3.25937177 3.25780122
#  3.25636384 3.25504834 3.25384439 3.25274253 3.25173411 3.25081119
#  3.24996653 3.2491935  3.24848601 3.24783852 3.24724593 3.24670359
#  3.24620724 3.24575297]
